# %% [markdown]
# <a href="https://colab.research.google.com/github/debvasconcellos/projeto002-laboratoria/blob/main/hipoteses_spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto: Hipóteses - Spotify (Laboratoria) - Débora Vasconcellos e Ana Guimarães

# %%
# Configurar o Pandas para exibir tabela completa
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
pd.set_option('display.max_columns', 41)
df.head(950)
# Out:
#     track_id                                         track_name  \
# 0    6909746                                    white christmas
# 1    3087104  the christmas song merry christmas to you rema...
# 2    4002890             a holly jolly christmas single version
# 3    6372609                                   jingle bell rock
# 4    8167749                      deck the hall remastered 1999
# ..       ...                                                ...
# 943  1274739                                            s class
# 944  4866757  all the way live spider man across the spider ...
# 945  5229182                                         pi man de
# 946  5168392      barbie world with aqua from barbie the album
# 947  7624098                                                s91
#
#                                         artist_s__name  artist_count  \
# 0    bing crosby john scott trotter his orchestra k...             3
# 1                                        nat king cole             1
# 2                                            burl ives             1
# 3                                          bobby helms             1
# 4                                        nat king cole             1
# ..                                                 ...           ...
# 943                                         stray kids             1
# 944                   future lil uzi vert metro boomin             3
# 945                                     semicenk do u              2
# 946                         nicki minaj aqua ice spice             3
# 947                                            karol g             1
#
#      released_year  released_month  released_day release_date_concat  \
# 0             1942               1             1          1942-01-01
# 1             1946              11             1          1946-11-01
# 2             1952               1             1          1952-01-01
# 3             1957               1             1          1957-01-01
# 4             1959               1             1          1959-01-01
# ..             ...             ...           ...                 ...
# 943           2023               6             2          2023-06-02
# 944           2023               6             2          2023-06-02
# 945           2023               6             2          2023-06-02
# 946           2023               6            23          2023-06-23
# 947           2023               7            14          2023-07-14
#
#     release_year_month_concat  in_spotify_playlists  in_spotify_charts  \
# 0                     1942-01                 11940                  0
# 1                     1946-11                 11500                  0
# 2                     1952-01                  7930                  0
# 3                     1957-01                 10326                  0
# 4                     1959-01                  3299                  0
# ..                        ...                   ...                ...
# 943                   2023-06                   290                 19
# 944                   2023-06                   259                  0
# 945                   2023-06                   185                  3
# 946                   2023-06                  1117                 80
# 947                   2023-07                   525                 41
#
#        streams  in_apple_playlists  in_apple_charts  in_deezer_playlists  \
# 0    395591396                  73               79                  123
# 1    389771964                 140               72                  251
# 2    395591396                 108              120                   73
# 3    741301563                 165               99                  104
# 4    127027715                  65               39                   41
# ..         ...                 ...              ...                  ...
# 943   65496046                   9              101                    5
# 944   37126685                   5               17                    5
# 945   43522589                   5                6                    4
# 946   65156199                  82              145                   65
# 947   16011326                  34              115                   39
#
#      in_deezer_charts  bpm  danceability__  valence__  energy__  \
# 0                   0   96              23         19        25
# 1                   0  139              36         22        15
# 2                   0  140              67         81        36
# 3                   0  119              74         78        37
# 4                   0  107              69         96        36
# ..                ...  ...             ...        ...       ...
# 943                 0  105              89         67        78
# 944                 0  135              77         28        55
# 945                 1   98              73         45        62
# 946                16  144              77         75        58
# 947                 6  128              86         42        72
#
#      acousticness__  instrumentalness__  liveness__  speechiness__  \
# 0                91                   0          40              3
# 1                84                   0          11              4
# 2                64                   0          15              3
# 3                84                   0           6              3
# 4                81                   0           8              4
# ..              ...                 ...         ...            ...
# 943               9                   0           7             33
# 944              18                   0          22             15
# 945              28                   0          13             13
# 946              52                   0          23             25
# 947              59                   0           9             19
#
#      bpm_quartil bpm_categorizada  danceability_quartil  \
# 0              1            Baixo                     1
# 1              3            Baixo                     1
# 2              3            Baixo                     2
# 3              2            Baixo                     3
# 4              2            Baixo                     2
# ..           ...              ...                   ...
# 943            2            Baixo                     4
# 944            3            Baixo                     3
# 945            1            Baixo                     3
# 946            4             Alto                     3
# 947            3            Baixo                     4
#
#     danceability_categorizada  valence_quartil valence_categorizada  \
# 0                       Baixo                1                Baixo
# 1                       Baixo                1                Baixo
# 2                       Baixo                4                 Alto
# 3                       Baixo                4                 Alto
# 4                       Baixo                4                 Alto
# ..                        ...              ...                  ...
# 943                      Alto                3                Baixo
# 944                     Baixo                1                Baixo
# 945                     Baixo                2                Baixo
# 946                     Baixo                4                 Alto
# 947                      Alto                2                Baixo
#
#      energy_quartil energy_categorizada  acousticness_quartil  \
# 0                 1               Baixo                     4
# 1                 1               Baixo                     4
# 2                 1               Baixo                     4
# 3                 1               Baixo                     4
# 4                 1               Baixo                     4
# ..              ...                 ...                   ...
# 943               4                Alto                     2
# 944               2               Baixo                     2
# 945               2               Baixo                     3
# 946               2               Baixo                     4
# 947               3               Baixo                     4
#
#     acousticness_categorizada  instrumentalness_quartil  \
# 0                        Alto                         4
# 1                        Alto                         1
# 2                        Alto                         4
# 3                        Alto                         3
# 4                        Alto                         1
# ..                        ...                       ...
# 943                     Baixo                         2
# 944                     Baixo                         3
# 945                     Baixo                         4
# 946                      Alto                         1
# 947                      Alto                         3
#
#     instrumentalness_categorizada  liveness_quartil liveness_categorizada  \
# 0                            Alto                 4                  Alto
# 1                           Baixo                 2                 Baixo
# 2                            Alto                 3                 Baixo
# 3                           Baixo                 1                 Baixo
# 4                           Baixo                 1                 Baixo
# ..                            ...               ...                   ...
# 943                         Baixo                 1                 Baixo
# 944                         Baixo                 3                 Baixo
# 945                          Alto                 3                 Baixo
# 946                         Baixo                 3                 Baixo
# 947                         Baixo                 1                 Baixo
#
#      speechiness_quartil speechiness_categorizada
# 0                      1                    Baixo
# 1                      1                    Baixo
# 2                      1                    Baixo
# 3                      1                    Baixo
# 4                      1                    Baixo
# ..                   ...                      ...
# 943                    4                     Alto
# 944                    4                     Alto
# 945                    4                     Alto
# 946                    4                     Alto
# 947                    4                     Alto
#
# [948 rows x 40 columns]

# %% [markdown]
# ## Descrição Estatística Simples

# %%
#Descrição Estatística
print(df.describe())
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    948.000000     948.000000      948.000000    948.000000
# mean       1.559072    2018.371308        6.047468     13.938819
# std        0.894481      10.653083        3.565774      9.186123
# min        1.000000    1942.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  \
# count            948.000000         948.000000  9.480000e+02
# mean            5209.739451          12.072785  5.143365e+08
# std             7914.448305          19.608092  5.677971e+08
# min               31.000000           0.000000  2.762000e+03
# 25%              874.500000           0.000000  1.416362e+08
# 50%             2216.500000           3.000000  2.891651e+08
# 75%             5573.750000          16.000000  6.729425e+08
# max            52898.000000         147.000000  3.703895e+09
#
#        in_apple_playlists  in_apple_charts  in_deezer_playlists  \
# count          948.000000       948.000000           948.000000
# mean            67.875527        52.046414           386.750000
# std             86.399243        50.671082          1133.290693
# min              0.000000         0.000000             0.000000
# 25%             13.000000         7.000000            13.000000
# 50%             34.000000        38.500000            44.000000
# 75%             88.000000        87.000000           164.250000
# max            672.000000       275.000000         12367.000000
#
#        in_deezer_charts         bpm  danceability__   valence__    energy__  \
# count        948.000000  948.000000      948.000000  948.000000  948.000000
# mean           2.658228  122.473629       66.971519   51.395570   64.258439
# std            6.019615   28.047409       14.646710   23.513789   16.583591
# min            0.000000   65.000000       23.000000    4.000000    9.000000
# 25%            0.000000   99.000000       57.000000   32.000000   53.000000
# 50%            0.000000  120.500000       69.000000   51.000000   66.000000
# 75%            2.000000  140.000000       78.000000   70.000000   77.000000
# max           58.000000  206.000000       96.000000   97.000000   97.000000
#
#        acousticness__  instrumentalness__  liveness__  speechiness__  \
# count      948.000000          948.000000  948.000000     948.000000
# mean        27.160338            1.568565   18.168776      10.155063
# std         26.024755            8.410065   13.705724       9.932731
# min          0.000000            0.000000    3.000000       2.000000
# 25%          6.000000            0.000000   10.000000       4.000000
# 50%         18.000000            0.000000   12.000000       6.000000
# 75%         43.000000            0.000000   23.000000      11.000000
# max         97.000000           91.000000   97.000000      64.000000
#
#        bpm_quartil  danceability_quartil  valence_quartil  energy_quartil  \
# count   948.000000            948.000000       948.000000      948.000000
# mean      2.500000              2.500000         2.500000        2.500000
# std       1.118624              1.118624         1.118624        1.118624
# min       1.000000              1.000000         1.000000        1.000000
# 25%       1.750000              1.750000         1.750000        1.750000
# 50%       2.500000              2.500000         2.500000        2.500000
# 75%       3.250000              3.250000         3.250000        3.250000
# max       4.000000              4.000000         4.000000        4.000000
#
#        acousticness_quartil  instrumentalness_quartil  liveness_quartil  \
# count            948.000000                948.000000        948.000000
# mean               2.500000                  2.500000          2.500000
# std                1.118624                  1.118624          1.118624
# min                1.000000                  1.000000          1.000000
# 25%                1.750000                  1.750000          1.750000
# 50%                2.500000                  2.500000          2.500000
# 75%                3.250000                  3.250000          3.250000
# max                4.000000                  4.000000          4.000000
#
#        speechiness_quartil
# count           948.000000
# mean              2.500000
# std               1.118624
# min               1.000000
# 25%               1.750000
# 50%               2.500000
# 75%               3.250000
# max               4.000000

# %% [markdown]
# ## Teste de Correlação R de Pearson

# %% [markdown]
# ### Correlação e Características das músicas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculando correlações
# Correlação entre as Características das músicas e Streams:
correlation_matrix = df[['bpm' , 'danceability__', 'energy__', 'acousticness__' , 'instrumentalness__' , 'liveness__' ,'speechiness__','streams']].corr()

# Plotando heatmap de correlações
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap='Greens')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Correlação Número de Músicas por Artistas e Total de Streams

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculando correlações
# Correlação entre Número de músicas por artistas e Total de Streams:
df = pd.read_csv('/content/drive/MyDrive/Laboratoria - Projeto 2/artists-count-streams.csv')
correlation_matrix = df[['total_musicas', 'total_streams']].corr()

# Plotando heatmap de correlações
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Correlação entre feats e streams

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculando correlações
# Correlação entre as quantidade de artistas (feats) e streams:
df = pd.read_csv('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
correlation_matrix = df[['artist_count' , 'streams']].corr()

# Plotando heatmap de correlações
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",cmap='Blues')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Teste de Correlação de Spearman

# %% [markdown]
# ### Correlação Charts Spotify e Apple

# %%
#Importe as bibliotecas necessárias
import pandas as pd
from scipy.stats import spearmanr
import seaborn as sns
import matplotlib.pyplot as plt


#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')

# Calcule a correlação
correlation, p_value = spearmanr(df["in_spotify_charts"], df["in_apple_charts"])
print(f"A correlação de Spearman é: {correlation:.4f}")
print(f"O valor-p é: {p_value:.4f}")

# Visualize a correlação
def display_correlation(df):
    r = df[["in_spotify_charts", "in_apple_charts"]].corr(method="spearman")
    plt.figure(figsize=(10, 6))
    heatmap = sns.heatmap(r, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
    plt.title("Spearman Correlation")
    plt.show()

# Chame a função para exibir o gráfico
display_correlation(df)
# Out:
# A correlação de Spearman é: 0.5210
# O valor-p é: 0.0000

# %% [markdown]
# ### Correlação Charts Spotify e Deezer

# %%
#Importe as bibliotecas necessárias
import pandas as pd
from scipy.stats import spearmanr
import seaborn as sns
import matplotlib.pyplot as plt


#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')

# Calcule a correlação
correlation, p_value = spearmanr(df["in_spotify_charts"], df["in_deezer_charts"])
print(f"A correlação de Spearman é: {correlation:.4f}")
print(f"O valor-p é: {p_value:.4f}")

# Visualize a correlação
def display_correlation(df):
    r = df[["in_spotify_charts", "in_deezer_charts"]].corr(method="spearman")
    plt.figure(figsize=(10, 6))
    heatmap = sns.heatmap(r, vmin=-1, vmax=1, annot=True, cmap='coolwarm')
    plt.title("Spearman Correlation")
    plt.show()

# Chame a função para exibir o gráfico
display_correlation(df)
# Out:
# A correlação de Spearman é: 0.5913
# O valor-p é: 0.0000

# %% [markdown]
# ##Teste de Mann-Whitney

# %% [markdown]
# ### Amostras BPM Alto e Baixo e Comportamento de Streams

# %%
#mannwhitneyu
#comparar as distribuições de duas amostras independentes (variáveis ordinais)

#bpm_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["bpm_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["bpm_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 87288.0000
# P-value: 0.4059
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Danceability Alto e Baixo e Comportamento de Streams

# %%
#danceability_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["danceability_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["danceability_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 75883.0000
# P-value: 0.0219
# Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Energy Alto e Baixo e Comportamento de Streams

# %%
#energy_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["energy_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["energy_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 80551.0000
# P-value: 0.3105
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Acousticness Alto e Baixo e Comportamento de Streams

# %%
#acousticness_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["acousticness_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["acousticness_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 82312.0000
# P-value: 0.5949
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Instrumentalness Alto e Baixo e Comportamento de Streams

# %%
#instrumentalness_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["instrumentalness_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["instrumentalness_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 86706.5000
# P-value: 0.5017
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Liveness Alto e Baixo e Comportamento de Streams

# %%
#liveness_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["liveness_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["liveness_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 80072.0000
# P-value: 0.2521
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Speechiness Alto e Baixo e Comportamento de Streams

# %%
#speechiness_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["speechiness_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["speechiness_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 75580.0000
# P-value: 0.0175
# Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.

# %% [markdown]
# ### Amostras Valence Alto e Baixo e Comportamento de Streams

# %%
#valence_categorizada-> alto/baixo

import pandas as pd
from scipy.stats import mannwhitneyu

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')
#Separe os dados em grupos 'alto' e 'baixo'

group_alto = df[df["valence_categorizada"] == "Alto"]["streams"]
group_baixo = df[df["valence_categorizada"] == "Baixo"]["streams"]

#Execute o teste de Mann-Whitney U
estatistica, p_value = mannwhitneyu(group_alto, group_baixo, alternative="two-sided")

#Imprima os resultados
print(f"Mann-Whitney U statistic: {estatistica:.4f}")
print(f"P-value: {p_value:.4f}")

#Verifique se o p-value é significativo

if p_value < 0.05:
    print("Rejeite a hipótese nula: Há uma diferença significativa entre os grupos.")
else:
    print("Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.")
# Out:
# Mann-Whitney U statistic: 80463.5000
# P-value: 0.2992
# Não rejeite a hipótese nula: Não há diferença significativa entre os grupos.

# %% [markdown]
# ## Regressão Linear

# %% [markdown]
# ### Independente: Presença total em playlists Dependente: Streams

# %%
#Regressão Linear
#Importe bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/hipoteses_spotify_full_table.csv')

#Plote o Gráfico de Dispersão e Calcule o índice de correlação

X=df['total_playlists'].values
Y=df['streams'].values

r=pearsonr(X,Y)
print (f'Coeficiente de correlação:{r}')

#Separe dados de treino e teste
#Utilize 70% dos dados para treino e o restante (30%) para teste
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

#Precisa redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

#Treine o modelo
reg=LinearRegression()
reg.fit(x_train,y_train)
pred=reg.predict(x_test)

plt.scatter(X,Y,color="blue")
plt.plot(x_test, pred, color="red")
plt.title ("Total Presença em Playlists vs Streams")
plt.xlabel("Total Playlists")
plt.ylabel("Streams (Bilhão)")
# Out:
# Coeficiente de correlação:PearsonRResult(statistic=0.7832450109547366, pvalue=1.8025640667977528e-197)
# Text(0, 0.5, 'Streams (Bilhão)')

# %%
#Verifique a representação do modelo
r_squared=r2_score(y_test, pred)
print(f'Coeficiente r2:{r_squared}')

residual = y_test - pred

plt.title('Resíduos')
plt.xlabel('Resíduos (streams)')
plt.ylabel('Frequência Absoluta')
plt.hist(residual, rwidth=0.9)
plt.show()
# Out:
# Coeficiente r2:0.6233807673644962

# %% [markdown]
# ### Independente: BPM  Dependente: Streams

# %%
#Regressão Linear
#Importe bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/hipoteses_spotify_full_table.csv')

#Plote o Gráfico de Dispersão e Calcule o índice de correlação

X=df['bpm'].values
Y=df['streams'].values

r=pearsonr(X,Y)
print (f'Coeficiente de correlação:{r}')

#Separe dados de treino e teste
#Utilize 70% dos dados para treino e o restante (30%) para teste
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

#Precisa redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

#Treine o modelo
reg=LinearRegression()
reg.fit(x_train,y_train)
pred=reg.predict(x_test)

plt.scatter(X,Y,color="blue")
plt.plot(x_test, pred, color="red")
plt.title ("Batidas Por Minuto vs Streams")
plt.xlabel("BPM")
plt.ylabel("Streams")
# Out:
# Coeficiente de correlação:PearsonRResult(statistic=-0.0023050669108387483, pvalue=0.9434944038809814)
# Text(0, 0.5, 'Streams')

# %%
#Verifique a representação do modelo
r_squared=r2_score(y_test, pred)
print(f'Coeficiente r2:{r_squared}')

residual = y_test - pred

plt.title('Resíduos')
plt.xlabel('Resíduos (streams)')
plt.ylabel('Frequência Absoluta')
plt.hist(residual, rwidth=0.9)
plt.show()
# Out:
# Coeficiente r2:-0.0062367171131918475

# %% [markdown]
# ### Independente: Ano de Lançamento Dependente: Streams

# %%
#Regressão Linear
#Importe bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/hipoteses_spotify_full_table.csv')

#Plote o Gráfico de Dispersão e Calcule o índice de correlação

X=df['released_year'].values
Y=df['streams'].values

r=pearsonr(X,Y)
print (f'Coeficiente de correlação:{r}')

#Separe dados de treino e teste
#Utilize 70% dos dados para treino e o restante (30%) para teste
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

#Precisa redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

#Treine o modelo
reg=LinearRegression()
reg.fit(x_train,y_train)
pred=reg.predict(x_test)

plt.scatter(X,Y,color="blue")
plt.plot(x_test, pred, color="red")
plt.title ("Ano de Lançamento vs Streams")
plt.xlabel("Anos")
plt.ylabel("Streams (Bilhão)")
# Out:
# Coeficiente de correlação:PearsonRResult(statistic=-0.24592672564565882, pvalue=1.5877757504943375e-14)
# Text(0, 0.5, 'Streams (Bilhão)')

# %%
#Verifique a representação do modelo
r_squared=r2_score(y_test, pred)
print(f'Coeficiente r2:{r_squared}')

residual = y_test - pred

plt.title('Resíduos')
plt.xlabel('Resíduos (streams)')
plt.ylabel('Frequência Absoluta')
plt.hist(residual, rwidth=0.9)
plt.show()
# Out:
# Coeficiente r2:0.06722922631942241

# %% [markdown]
# ### Independente: BPM Alto Dependente: Streams

# %%
#Regressão Linear
#Importe bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/full_table_spotify_quartis.csv')

#Plote o Gráfico de Dispersão e Calcule o índice de correlação

df=df[df['bpm_categorizada']=='Alto']

X=df['bpm'].values
Y=df['streams'].values

r=pearsonr(X,Y)
print (f'Coeficiente de correlação:{r}')

#Separe dados de treino e teste
#Utilize 70% dos dados para treino e o restante (30%) para teste
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

#Precisa redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

#Treine o modelo
reg=LinearRegression()
reg.fit(x_train,y_train)
pred=reg.predict(x_test)

plt.scatter(X,Y,color="blue")
plt.plot(x_test, pred, color="red")
plt.title ("Batidas Por Minuto (Alto) vs Streams")
plt.xlabel("BPM")
plt.ylabel("Streams")
# Out:
# Coeficiente de correlação:PearsonRResult(statistic=0.14687094827972005, pvalue=0.023736223542605985)
# Text(0, 0.5, 'Streams')

# %%
#Verifique a representação do modelo
r_squared=r2_score(y_test, pred)
print(f'Coeficiente r2:{r_squared}')

residual = y_test - pred

plt.title('Resíduos')
plt.xlabel('Resíduos (streams)')
plt.ylabel('Frequência Absoluta')
plt.hist(residual, rwidth=0.9)
plt.show()
# Out:
# Coeficiente r2:-0.037339771454757864

# %% [markdown]
# ### Independente: Total de Músicas por Artista Dependente: Total de Streams

# %%
#Regressão Linear
#Importe bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

#Carregue os dados reais
df = pd.read_csv ('/content/drive/MyDrive/Laboratoria - Projeto 2/artists-count-streams.csv')

#Plote o Gráfico de Dispersão e Calcule o índice de correlação

X=df['total_musicas'].values
Y=df['total_streams'].values

r=pearsonr(X,Y)
print (f'Coeficiente de correlação:{r}')

#Separe dados de treino e teste
#Utilize 70% dos dados para treino e o restante (30%) para teste
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)

#Precisa redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

#Treine o modelo
reg=LinearRegression()
reg.fit(x_train,y_train)
pred=reg.predict(x_test)

plt.scatter(X,Y,color="blue")
plt.plot(x_test, pred, color="red")
plt.title ("Número de Músicas Totais por Artista vs Total de Streams")
plt.xlabel("Total de Músicas p/Artista")
plt.ylabel("Total de Streams")
# Out:
# Coeficiente de correlação:PearsonRResult(statistic=0.7789441982622813, pvalue=3.11374567674711e-132)
# Text(0, 0.5, 'Total de Streams')

# %%
#Verifique a representação do modelo
r_squared=r2_score(y_test, pred)
print(f'Coeficiente r2:{r_squared}')

residual = y_test - pred

plt.title('Resíduos')
plt.xlabel('Resíduos (streams)')
plt.ylabel('Frequência Absoluta')
plt.hist(residual, rwidth=0.9)
plt.show()
# Out:
# Coeficiente r2:0.5699160693481193
